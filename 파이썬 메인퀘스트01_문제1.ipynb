# %%
import random

class account:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
        self.bank_name = "SC은행"
        self.account_number = self.__random_unmber()

        def __random_number(self):
            while True:
                p1 = random.randint(0, 999)
                p2 = random.randint(0, 99)
                p3 = random.randint(0, 999999)
                new_num =f"{p1:03d}-{p2:02d}-{p3:06d}"

        print(f"{self.bank_name} 계좌가 개설되었습니다.")

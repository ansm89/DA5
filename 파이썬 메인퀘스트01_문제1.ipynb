# %%
class account:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
        self.bank_name = "SC은행"
        self.account_number = ""

        self.random_account_number()
        print(f"{self.bank_name} 계좌가 개설되었습니다.")
